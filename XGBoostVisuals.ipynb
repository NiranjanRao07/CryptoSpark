# %%
from pyspark.sql.functions import lead
from pyspark.ml.feature import VectorAssembler
from pyspark.sql.functions import monotonically_increasing_id
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import input_file_name, col, regexp_extract
from pyspark.sql import functions as F
from xgboost.spark import SparkXGBRegressor
import re
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql import functions as F


#"ml.dmlc:xgboost4j-spark_2.12:1.5.1"

spark = SparkSession.builder \
    .appName("S3 USDT Parquet Reader") \
    .config("spark.jars.packages",
            "org.apache.hadoop:hadoop-aws:3.3.4,"
            "com.amazonaws:aws-java-sdk-bundle:1.12.568") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.access.key", "AKIA2WFFOP3DIZ7VCICR") \
    .config("spark.hadoop.fs.s3a.secret.key", "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") \
    .config("spark.hadoop.fs.s3a.endpoint", "s3.us-east-1.amazonaws.com") \
    .getOrCreate()
s3_path = "s3a://cryptospark-dataset/processed-data/*-USDT/*"  # matches all part files
df = spark.read.parquet(s3_path)
# Out:
# 25/05/09 19:52:47 WARN Utils: Your hostname, Olivers-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 172.16.186.49 instead (on interface en0)
# 25/05/09 19:52:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/Users/oliverzheng/spark-3.5.3-bin-hadoop3/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/oliverzheng/.ivy2/cache
# The jars for the packages stored in: /Users/oliverzheng/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-7f06e8b2-ba3c-4954-912a-c87203cb31a2;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.568 in central
# :: resolution report :: resolve 282ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.568 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	:: evicted modules:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 by [com.amazonaws#aws-java-sdk-bundle;1.12.568] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   4   |   0   |   0   |   1   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-7f06e8b2-ba3c-4954-912a-c87203cb31a2
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/11ms)
# 25/05/09 19:52:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/09 19:52:50 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/05/09 19:52:58 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
xgb = SparkXGBRegressor(
    features_col="features",
    label_col="target",
    prediction_col="prediction",
    max_depth=6,
    eta=0.1,
    objective="reg:squarederror",
    num_workers=4  
)



def process_crypto_df(symbol, s3_path):
    df = spark.read.parquet(s3_path)

    # Optional: apply log1p to reduce skew
    w = Window.orderBy("date")
    df = df.withColumn("target", F.lead("close", 30).over(w))
    df = df.dropna(subset=["target"])

    # Average price to check for low price
    avg_price = df.select(F.mean("close")).collect()[0][0]

    feature_cols = ["open", "high", "low", "close", "volume", 
                    "daily_return", "volatility", "ma_7", "ma_30"]
    assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
    df_model = assembler.transform(df).select("features", "target")

    count = df_model.count()
    train_count = int(count * 0.8)
    df_model = df_model.withColumn("row_id", monotonically_increasing_id())
    train_df = df_model.filter(col("row_id") < train_count).drop("row_id")
    test_df = df_model.filter(col("row_id") >= train_count).drop("row_id")

    model = xgb.fit(train_df)
    predictions = model.transform(test_df)

    # Metrics
    evaluator_mse = RegressionEvaluator(labelCol="target", predictionCol="prediction", metricName="mse")
    evaluator_mae = RegressionEvaluator(labelCol="target", predictionCol="prediction", metricName="mae")
    evaluator_r2 = RegressionEvaluator(labelCol="target", predictionCol="prediction", metricName="r2")

    mse = evaluator_mse.evaluate(predictions)
    mae = evaluator_mae.evaluate(predictions)
    r2 = evaluator_r2.evaluate(predictions)

    # Accuracy within ±5%
    threshold = 0.05
    accuracy_df = predictions.withColumn(
        "accuracy",
        (F.abs(F.col("prediction") - F.col("target")) / F.col("target") <= threshold).cast("int")
    )
    accuracy = accuracy_df.agg({"accuracy": "mean"}).collect()[0][0]

    # Flag possible inflated accuracy
    if avg_price < 0.1 and accuracy > 0.8:
        print(f"⚠️  {symbol} might have inflated accuracy due to low average price ({avg_price:.4f})")

    print(f"📊 {symbol}: MSE={mse:.4f}, MAE={mae:.4f}, R²={r2:.4f},  Accuracy (±5%)={accuracy*100:.2f}%")

    return symbol, accuracy, mse, mae, r2

# %%
df_with_filepath = df.withColumn("filepath", F.input_file_name())

# Get distinct file paths
distinct_df = df_with_filepath.select("filepath").distinct()

# Extract the crypto name from the file path
df_with_crypto = distinct_df.withColumn(
    "crypto_name", 
    F.regexp_extract(F.col("filepath"), r"processed-data/([^/]+)-USDT/", 1)
)

# Show the result
df_with_crypto.show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# |filepath                                                                                                              |crypto_name|
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# |s3a://cryptospark-dataset/processed-data/XRP-USDT/part-00000-816f4245-258b-4699-ac5e-feded09865d0-c000.snappy.parquet |XRP        |
# |s3a://cryptospark-dataset/processed-data/IOTA-USDT/part-00000-ee5b10c8-1379-4b6b-8190-ad5941d80349-c000.snappy.parquet|IOTA       |
# |s3a://cryptospark-dataset/processed-data/ICX-USDT/part-00000-a9c43b4b-73b9-45a8-ba7d-5eb4234dc022-c000.snappy.parquet |ICX        |
# |s3a://cryptospark-dataset/processed-data/NULS-USDT/part-00000-34199826-d916-4c52-94d9-9fd91e9f5198-c000.snappy.parquet|NULS       |
# |s3a://cryptospark-dataset/processed-data/FET-USDT/part-00000-d783d771-1318-406e-ab3f-1868d3376f2b-c000.snappy.parquet |FET        |
# |s3a://cryptospark-dataset/processed-data/ENJ-USDT/part-00000-73e48cd1-23bc-4e48-b6ea-139149fd40e2-c000.snappy.parquet |ENJ        |
# |s3a://cryptospark-dataset/processed-data/BCH-USDT/part-00000-10e282c7-8cba-4de9-9add-f100e583dbf6-c000.snappy.parquet |BCH        |
# |s3a://cryptospark-dataset/processed-data/ZIL-USDT/part-00000-8dab52e8-8d31-4906-9f64-0a33724a70b5-c000.snappy.parquet |ZIL        |
# |s3a://cryptospark-dataset/processed-data/FTM-USDT/part-00000-1c70ac2b-d118-44ce-b2c8-446452d9dce2-c000.snappy.parquet |FTM        |
# |s3a://cryptospark-dataset/processed-data/REN-USDT/part-00000-f0108242-a385-453e-880f-e22e5bf45a2f-c000.snappy.parquet |REN        |
# |s3a://cryptospark-dataset/processed-data/WAN-USDT/part-00000-e4827b0b-b3b4-4ff5-92ca-abef865a9d29-c000.snappy.parquet |WAN        |
# |s3a://cryptospark-dataset/processed-data/PERL-USDT/part-00000-325eb250-131d-4a3c-b7a4-35362a82e02c-c000.snappy.parquet|PERL       |
# |s3a://cryptospark-dataset/processed-data/LTO-USDT/part-00000-5a72eb0f-3150-4df5-88ab-bd29bb76e9e6-c000.snappy.parquet |LTO        |
# |s3a://cryptospark-dataset/processed-data/DOT-USDT/part-00000-b477ff00-53af-4301-9c52-6e63623cc906-c000.snappy.parquet |DOT        |
# |s3a://cryptospark-dataset/processed-data/SRM-USDT/part-00000-ffcc10c0-4c03-4da8-a7bc-ca8959eca8c5-c000.snappy.parquet |SRM        |
# |s3a://cryptospark-dataset/processed-data/YFII-USDT/part-00000-4dd64690-dcef-48bb-9449-8b6638582874-c000.snappy.parquet|YFII       |
# |s3a://cryptospark-dataset/processed-data/AXS-USDT/part-00000-19f08308-1db6-405d-be5f-9423d9294cce-c000.snappy.parquet |AXS        |
# |s3a://cryptospark-dataset/processed-data/DATA-USDT/part-00000-43071e52-380a-4e12-8ef9-71cb40ec2cde-c000.snappy.parquet|DATA       |
# |s3a://cryptospark-dataset/processed-data/KSM-USDT/part-00000-7911a548-561e-41e7-b4a8-d681b34fce3d-c000.snappy.parquet |KSM        |
# |s3a://cryptospark-dataset/processed-data/MBL-USDT/part-00000-5e267ae5-51b8-4a42-99ca-161b1964bfea-c000.snappy.parquet |MBL        |
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# only showing top 20 rows

# %%
results = []


for row in df_with_crypto.collect():
    crypto_name = row["crypto_name"]
    filepath = row["filepath"]
    metrics = process_crypto_df(crypto_name, filepath)
    results.append(metrics)
# Out:
# 25/05/09 19:53:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:53:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:54:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:54:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:54:11,270 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:54:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:54:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:54:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:54:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:54:56,294 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:54:57] Task 0 got rank 0[19:54:57] Task 3 got rank 3
#
# [19:54:57] Task 2 got rank 2
# [19:54:57] Task 1 got rank 1
# 2025-05-09 19:55:05,866 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:55:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:55:27,650 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:55:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:55:49,897 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:55:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:55:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:56:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:56:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:56:18,523 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:56:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:56:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:56:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:56:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:57:11,777 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 XRP: MSE=0.0000, MAE=0.0033, R²=0.9993,  Accuracy (±5%)=99.90%
# 25/05/09 19:57:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:57:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:58:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:58:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:58:29,966 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:58:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:58:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:58:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:58:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:59:01,230 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:59:02] Task 1 got rank 1[19:59:02] Task 2 got rank 2
# [19:59:02] Task 0 got rank 0
#
# [19:59:02] Task 3 got rank 3
# 2025-05-09 19:59:10,699 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:59:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:59:30,016 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:59:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:59:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:00:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:00:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:00:38,537 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:00:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:00:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:00:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:01:02,353 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:01:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:01:21,005 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 IOTA: MSE=0.0000, MAE=0.0036, R²=0.9997,  Accuracy (±5%)=99.89%
# 25/05/09 20:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:02:03,060 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:02:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:02:34,823 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:02:35] Task 2 got rank 2
# [20:02:35] Task 3 got rank 3
# [20:02:35] Task 0 got rank 0
# [20:02:35] Task 1 got rank 1
# 2025-05-09 20:02:47,399 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:02:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:02:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:03:01,022 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:03:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:03:16,761 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:03:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:03:41,413 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:03:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:03:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:04:09,354 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 ICX: MSE=0.0000, MAE=0.0034, R²=0.9996,  Accuracy (±5%)=99.77%
# 25/05/09 20:04:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:04:45,565 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:04:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:04:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:05:06,746 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [20:05:07] Task 0 got rank 0                                        (0 + 4) / 4]
# [20:05:07] Task 3 got rank 3
# [20:05:07] Task 2 got rank 2
# [20:05:07] Task 1 got rank 1
# 2025-05-09 20:05:17,145 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:05:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:05:34,693 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:05:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:05:50,142 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:05:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:05:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:06:09,203 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:06:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:06:27,527 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 NULS: MSE=0.0000, MAE=0.0030, R²=0.9983,  Accuracy (±5%)=95.78%
# 25/05/09 20:06:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:06:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:07:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:07:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:07:16,103 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:07:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:07:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:07:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:07:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:07:56,266 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:07:57] Task 1 got rank 1
# [20:07:57] Task 0 got rank 0
# [20:07:57] Task 3 got rank 3
# [20:07:57] Task 2 got rank 2
# 2025-05-09 20:08:05,688 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:08:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:08:18,634 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:08:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:08:37,690 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:08:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:08:50,588 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:08:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:08:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:09:26,769 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 FET: MSE=0.0000, MAE=0.0015, R²=0.9995,  Accuracy (±5%)=99.56%
# 25/05/09 20:09:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:09:51,651 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:09:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:09:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:10:09,994 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:10:11] Task 0 got rank 0
# [20:10:11] Task 1 got rank 1
# [20:10:11] Task 3 got rank 3
# [20:10:11] Task 2 got rank 2
# 2025-05-09 20:10:20,815 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:10:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:10:31,952 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:10:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:10:44,579 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:10:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:10:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:11:01,979 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:11:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:11:28,846 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 ENJ: MSE=0.0048, MAE=0.0318, R²=0.9743,  Accuracy (±5%)=81.61%
# 25/05/09 20:11:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:11:46,896 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:11:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:11:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:12:01,156 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [20:12:02] Task 0 got rank 0                                        (0 + 4) / 4]
# [20:12:02] Task 1 got rank 1
# [20:12:02] Task 2 got rank 2
# [20:12:02] Task 3 got rank 3
# 2025-05-09 20:12:09,436 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:12:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:12:22,234 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:12:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:12:39,539 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:12:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:12:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:12:54,917 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# ...
# 2025-05-09 21:00:33,992 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:00:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:00:39,792 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:00:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:00:46,765 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 JUV: MSE=0.0060, MAE=0.0465, R²=0.9928,  Accuracy (±5%)=96.62%
# 25/05/09 21:00:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:00:57,219 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 21:00:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:00:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:04,070 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [21:01:05] Task 1 got rank 1                                        (0 + 4) / 4]
# [21:01:05] Task 2 got rank 2
# [21:01:05] Task 0 got rank 0
# [21:01:05] Task 3 got rank 3
# 2025-05-09 21:01:08,985 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 21:01:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:13,973 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:01:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:19,578 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:01:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:25,293 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:01:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:31,319 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 📊 FIS: MSE=0.0001, MAE=0.0056, R²=0.9529,  Accuracy (±5%)=91.70%
# 25/05/09 21:01:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:39,648 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 21:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:46,716 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [21:01:47] Task 1 got rank 1[21:01:47] Task 2 got rank 2            (0 + 4) / 4]
#
# [21:01:47] Task 0 got rank 0
# [21:01:47] Task 3 got rank 3
# 2025-05-09 21:01:50,858 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 21:01:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:54,670 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:01:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:01:59,113 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:01:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:01:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:02:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:02:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:02:03,253 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 21:02:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:02:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:02:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 21:02:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 21:02:08,851 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# [Stage 1048:>                                                       (0 + 1) / 1]
# 📊 EPS: MSE=0.0000, MAE=0.0022, R²=0.9889,  Accuracy (±5%)=98.84%

# %%
from pyspark.sql.functions import round

results_df_rounded = results_df.withColumn("accuracy", round("accuracy", 2)) \
                               .withColumn("mse", round("mse", 2)) \
                               .withColumn("mae", round("mae", 2)) \
                               .withColumn("r2", round("r2", 2))

# Show all rows without truncation
results_df_rounded.orderBy("accuracy").show(n=results_df_rounded.count(), truncate=False)
# Out:
# +------+--------+--------+-----+-----+
# |symbol|accuracy|mse     |mae  |r2   |
# +------+--------+--------+-----+-----+
# |BCH   |0.27    |2015.37 |37.75|0.5  |
# |DATA  |0.29    |0.0     |0.0  |-0.51|
# |BAL   |0.31    |1.41    |0.93 |-0.66|
# |GTC   |0.47    |0.06    |0.18 |0.75 |
# |SRM   |0.49    |0.02    |0.07 |0.35 |
# |YFII  |0.6     |13456.94|76.36|0.92 |
# |GRT   |0.73    |0.0     |0.01 |0.73 |
# |FIL   |0.79    |0.1     |0.2  |0.92 |
# |ENJ   |0.82    |0.0     |0.03 |0.97 |
# |DNT   |0.82    |0.0     |0.0  |0.8  |
# |DOT   |0.82    |0.06    |0.19 |0.93 |
# |REN   |0.82    |0.0     |0.0  |1.0  |
# |REEF  |0.85    |0.0     |0.0  |0.96 |
# |HNT   |0.88    |0.06    |0.15 |0.99 |
# |ZIL   |0.9     |0.0     |0.0  |1.0  |
# |WING  |0.92    |0.18    |0.14 |0.99 |
# |FIS   |0.92    |0.0     |0.01 |0.95 |
# |TCT   |0.95    |0.0     |0.0  |1.0  |
# |AXS   |0.95    |0.11    |0.22 |0.99 |
# |KNC   |0.95    |0.0     |0.01 |0.99 |
# |SHIB  |0.95    |0.0     |0.0  |0.96 |
# |NULS  |0.96    |0.0     |0.0  |1.0  |
# |1INCH |0.96    |0.0     |0.01 |0.97 |
# |KSM   |0.97    |0.47    |0.48 |1.0  |
# |JUV   |0.97    |0.01    |0.05 |0.99 |
# |MBL   |0.98    |0.0     |0.0  |0.99 |
# |FTM   |0.98    |0.0     |0.01 |1.0  |
# |LTO   |0.99    |0.0     |0.0  |0.99 |
# |IDEX  |0.99    |0.0     |0.0  |0.98 |
# |PERL  |0.99    |0.0     |0.0  |1.0  |
# |EPS   |0.99    |0.0     |0.0  |0.99 |
# |FET   |1.0     |0.0     |0.0  |1.0  |
# |XRP   |1.0     |0.0     |0.0  |1.0  |
# |WAN   |1.0     |0.0     |0.0  |1.0  |
# |IOTA  |1.0     |0.0     |0.0  |1.0  |
# |ICX   |1.0     |0.0     |0.0  |1.0  |
# +------+--------+--------+-----+-----+

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert to pandas for visualization
top_cryptos_pd = results_df_rounded.toPandas()
# Set the figure size
plt.figure(figsize=(15, 8))

# Use seaborn to plot a grouped bar plot
sns.barplot(x='symbol', y='accuracy', data=top_cryptos_pd, color='blue', label='Accuracy')
sns.barplot(x='symbol', y='mse', data=top_cryptos_pd, color='orange', label='MSE')
sns.barplot(x='symbol', y='mae', data=top_cryptos_pd, color='green', label='MAE')
sns.barplot(x='symbol', y='r2', data=top_cryptos_pd, color='red', label='R2')

# Title and labels
plt.title('Top 10 Cryptocurrencies Model Performance', fontsize=18)
plt.xlabel('Cryptocurrency', fontsize=14)
plt.ylabel('Scores', fontsize=14)

# Rotate x-axis labels to avoid overlap
plt.xticks(rotation=90)

# Show the legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Apply log transformation (add a small constant to avoid log(0))
top_cryptos_pd['log_accuracy'] = np.log(top_cryptos_pd['accuracy'] + 1e-10)
top_cryptos_pd['log_mse'] = np.log(top_cryptos_pd['mse'] + 1e-10)
top_cryptos_pd['log_mae'] = np.log(top_cryptos_pd['mae'] + 1e-10)
top_cryptos_pd['log_r2'] = np.log(top_cryptos_pd['r2'] + 1e-10)

# Check the transformed data
top_cryptos_pd[['symbol', 'log_accuracy', 'log_mse', 'log_mae', 'log_r2']].head()
# Out:
# /Users/oliverzheng/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   symbol  log_accuracy    log_mse    log_mae        log_r2
# 0    XRP  1.000000e-10 -23.025851 -23.025851  1.000000e-10
# 1   IOTA  1.000000e-10 -23.025851 -23.025851  1.000000e-10
# 2    ICX  1.000000e-10 -23.025851 -23.025851  1.000000e-10
# 3   NULS -4.082199e-02 -23.025851 -23.025851  1.000000e-10
# 4    FET  1.000000e-10 -23.025851 -23.025851  1.000000e-10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(15, 8))

# Plot the log-transformed scores
sns.barplot(x='symbol', y='log_accuracy', data=top_cryptos_pd, color='blue', label='Log Accuracy')
sns.barplot(x='symbol', y='log_mse', data=top_cryptos_pd, color='orange', label='Log MSE')
sns.barplot(x='symbol', y='log_mae', data=top_cryptos_pd, color='green', label='Log MAE')
sns.barplot(x='symbol', y='log_r2', data=top_cryptos_pd, color='red', label='Log R2')

# Title and labels
plt.title('Top 10 Cryptocurrencies Model Performance (Log-transformed)', fontsize=18)
plt.xlabel('Cryptocurrency', fontsize=14)
plt.ylabel('Log-transformed Scores', fontsize=14)

# Rotate x-axis labels to avoid overlap
plt.xticks(rotation=90)

# Show the legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to create a radar plot
def radar_plot(df, crypto, metrics, labels):
    values = df.loc[df['symbol'] == crypto, metrics].values.flatten().tolist()
    
    # Normalize the values if necessary (e.g., scaling between 0 and 1)
    values = [((x - min(values)) / (max(values) - min(values))) for x in values]

    # Number of variables
    num_vars = len(metrics)

    # Compute angle of each axis
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

    # The plot is circular, so we need to "close the loop" and append the start value to the end.
    values += values[:1]
    angles += angles[:1]

    # Create the radar plot
    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
    ax.fill(angles, values, color='blue', alpha=0.25)
    ax.plot(angles, values, color='blue', linewidth=2)

    # Set the labels
    ax.set_yticklabels([])
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, fontsize=12)
    
    # Title
    ax.set_title(f'Radar Plot for {crypto}', size=16)
    plt.show()

# List of cryptocurrencies to plot and corresponding metrics
cryptos_to_plot = ['BCH', 'DATA', 'BAL', 'GTC', 'FIL', 'YFII', 'ENJ', 'DOT', 'REN', 'ZIL']
metrics = ['log_accuracy', 'log_mse', 'log_mae', 'log_r2']
labels = ['Accuracy', 'MSE', 'MAE', 'R2']

# Plot radar plot for each selected cryptocurrency
for crypto in cryptos_to_plot:
    radar_plot(top_cryptos_pd, crypto, metrics, labels)

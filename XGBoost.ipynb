# %%
from pyspark.sql.functions import lead
from pyspark.ml.feature import VectorAssembler
from pyspark.sql.functions import monotonically_increasing_id
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import input_file_name, col, regexp_extract
from pyspark.sql import functions as F
from xgboost.spark import SparkXGBRegressor
import re
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql import functions as F


#"ml.dmlc:xgboost4j-spark_2.12:1.5.1"

spark = SparkSession.builder \
    .appName("S3 USDT Parquet Reader") \
    .config("spark.jars.packages",
            "org.apache.hadoop:hadoop-aws:3.3.4,"
            "com.amazonaws:aws-java-sdk-bundle:1.12.568") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.access.key", "AKIA2WFFOP3DIZ7VCICR") \
    .config("spark.hadoop.fs.s3a.secret.key", "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") \
    .config("spark.hadoop.fs.s3a.endpoint", "s3.us-east-1.amazonaws.com") \
    .getOrCreate()
s3_path = "s3a://cryptospark-dataset/processed-data/*-USDT/*"  # matches all part files
df = spark.read.parquet(s3_path)
# Out:
# 25/05/09 19:34:34 WARN Utils: Your hostname, Olivers-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 172.16.186.49 instead (on interface en0)
# 25/05/09 19:34:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/Users/oliverzheng/spark-3.5.3-bin-hadoop3/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/oliverzheng/.ivy2/cache
# The jars for the packages stored in: /Users/oliverzheng/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-97a4b2c4-a3a8-4e79-a94d-f5600795e1a9;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.568 in central
# :: resolution report :: resolve 240ms :: artifacts dl 6ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.568 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	:: evicted modules:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 by [com.amazonaws#aws-java-sdk-bundle;1.12.568] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   4   |   0   |   0   |   1   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-97a4b2c4-a3a8-4e79-a94d-f5600795e1a9
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/4ms)
# 25/05/09 19:34:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/09 19:34:42 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
xgb = SparkXGBRegressor(
    features_col="features",
    label_col="target",
    prediction_col="prediction",
    max_depth=6,
    eta=0.1,
    objective="reg:squarederror",
    num_workers=4  
)



def process_crypto_df(symbol, s3_path):
    df = spark.read.parquet(s3_path)
    w = Window.orderBy("date")
    df = df.withColumn("target", F.lead("close", 30).over(Window.orderBy("date")))
    df = df.dropna(subset=["target"])
    feature_cols = ["open", "high", "low", "close", "volume", 
                "daily_return", "volatility", "ma_7", "ma_30"]
    assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
    df_model = assembler.transform(df).select("features", "target")
    count = df_model.count()
    train_count = int(count * 0.8)
    df_model = df_model.withColumn("row_id", monotonically_increasing_id())
    train_df = df_model.filter(col("row_id") < train_count).drop("row_id")
    test_df = df_model.filter(col("row_id") >= train_count).drop("row_id")
    model = xgb.fit(train_df)
    predictions = model.transform(test_df)
    evaluator_mse = RegressionEvaluator(labelCol="target", predictionCol="prediction", metricName="mse")
    mse = evaluator_mse.evaluate(predictions)
    threshold = 0.05 
    accuracy_df = predictions.withColumn(
        "accuracy",
        (F.abs(F.col("prediction") - F.col("target")) / F.col("target") <= threshold).cast("int")
    )
    accuracy = accuracy_df.agg({"accuracy": "mean"}).collect()[0][0]
    print(f"{symbol} Mean Squared Error (MSE): {mse}   Accuracy (within 5% of true values): {accuracy * 100:.2f}%")
    return  accuracy,mse,symbol

# %%
df_with_filepath = df.withColumn("filepath", F.input_file_name())

# Get distinct file paths
distinct_df = df_with_filepath.select("filepath").distinct()

# Extract the crypto name from the file path
df_with_crypto = distinct_df.withColumn(
    "crypto_name", 
    F.regexp_extract(F.col("filepath"), r"processed-data/([^/]+)-USDT/", 1)
)

# Show the result
df_with_crypto.show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# |filepath                                                                                                              |crypto_name|
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# |s3a://cryptospark-dataset/processed-data/XRP-USDT/part-00000-816f4245-258b-4699-ac5e-feded09865d0-c000.snappy.parquet |XRP        |
# |s3a://cryptospark-dataset/processed-data/IOTA-USDT/part-00000-ee5b10c8-1379-4b6b-8190-ad5941d80349-c000.snappy.parquet|IOTA       |
# |s3a://cryptospark-dataset/processed-data/ICX-USDT/part-00000-a9c43b4b-73b9-45a8-ba7d-5eb4234dc022-c000.snappy.parquet |ICX        |
# |s3a://cryptospark-dataset/processed-data/NULS-USDT/part-00000-34199826-d916-4c52-94d9-9fd91e9f5198-c000.snappy.parquet|NULS       |
# |s3a://cryptospark-dataset/processed-data/FET-USDT/part-00000-d783d771-1318-406e-ab3f-1868d3376f2b-c000.snappy.parquet |FET        |
# |s3a://cryptospark-dataset/processed-data/ENJ-USDT/part-00000-73e48cd1-23bc-4e48-b6ea-139149fd40e2-c000.snappy.parquet |ENJ        |
# |s3a://cryptospark-dataset/processed-data/BCH-USDT/part-00000-10e282c7-8cba-4de9-9add-f100e583dbf6-c000.snappy.parquet |BCH        |
# |s3a://cryptospark-dataset/processed-data/ZIL-USDT/part-00000-8dab52e8-8d31-4906-9f64-0a33724a70b5-c000.snappy.parquet |ZIL        |
# |s3a://cryptospark-dataset/processed-data/FTM-USDT/part-00000-1c70ac2b-d118-44ce-b2c8-446452d9dce2-c000.snappy.parquet |FTM        |
# |s3a://cryptospark-dataset/processed-data/REN-USDT/part-00000-f0108242-a385-453e-880f-e22e5bf45a2f-c000.snappy.parquet |REN        |
# |s3a://cryptospark-dataset/processed-data/WAN-USDT/part-00000-e4827b0b-b3b4-4ff5-92ca-abef865a9d29-c000.snappy.parquet |WAN        |
# |s3a://cryptospark-dataset/processed-data/PERL-USDT/part-00000-325eb250-131d-4a3c-b7a4-35362a82e02c-c000.snappy.parquet|PERL       |
# |s3a://cryptospark-dataset/processed-data/LTO-USDT/part-00000-5a72eb0f-3150-4df5-88ab-bd29bb76e9e6-c000.snappy.parquet |LTO        |
# |s3a://cryptospark-dataset/processed-data/DOT-USDT/part-00000-b477ff00-53af-4301-9c52-6e63623cc906-c000.snappy.parquet |DOT        |
# |s3a://cryptospark-dataset/processed-data/SRM-USDT/part-00000-ffcc10c0-4c03-4da8-a7bc-ca8959eca8c5-c000.snappy.parquet |SRM        |
# |s3a://cryptospark-dataset/processed-data/YFII-USDT/part-00000-4dd64690-dcef-48bb-9449-8b6638582874-c000.snappy.parquet|YFII       |
# |s3a://cryptospark-dataset/processed-data/AXS-USDT/part-00000-19f08308-1db6-405d-be5f-9423d9294cce-c000.snappy.parquet |AXS        |
# |s3a://cryptospark-dataset/processed-data/DATA-USDT/part-00000-43071e52-380a-4e12-8ef9-71cb40ec2cde-c000.snappy.parquet|DATA       |
# |s3a://cryptospark-dataset/processed-data/KSM-USDT/part-00000-7911a548-561e-41e7-b4a8-d681b34fce3d-c000.snappy.parquet |KSM        |
# |s3a://cryptospark-dataset/processed-data/MBL-USDT/part-00000-5e267ae5-51b8-4a42-99ca-161b1964bfea-c000.snappy.parquet |MBL        |
# +----------------------------------------------------------------------------------------------------------------------+-----------+
# only showing top 20 rows

# %%
for row in df_with_crypto.collect():
    crypto_name = row["crypto_name"]
    filepath = row["filepath"]
    process_crypto_df(crypto_name,filepath)
# Out:
# 25/05/09 19:35:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:35:28,535 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:35:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:35:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:36:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:36:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:36:34,596 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:36:35] Task 1 got rank 1
# [19:36:35] Task 2 got rank 2
# [19:36:35] Task 3 got rank 3
# [19:36:35] Task 0 got rank 0
# 2025-05-09 19:36:44,272 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:36:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:36:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:36:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:37:06,892 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:37:12 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:12 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:37:24,653 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# XRP Mean Squared Error (MSE): 2.588372996857082e-05   Accuracy (within 5% of true values): 99.90%
# 25/05/09 19:37:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:37:43,775 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:37:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:37:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:38:04,020 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:38:05] Task 1 got rank 1
# [19:38:05] Task 2 got rank 2
# [19:38:05] Task 0 got rank 0
# [19:38:05] Task 3 got rank 3
# 2025-05-09 19:38:12,962 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:38:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:38:45,104 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:38:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:38:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:39:00,310 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# IOTA Mean Squared Error (MSE): 3.3192722959088045e-05   Accuracy (within 5% of true values): 99.89%
# 25/05/09 19:39:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:39:17,333 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:39:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:39:35,034 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:39:36] Task 1 got rank 1                                        (0 + 4) / 4]
# [19:39:36] Task 2 got rank 2
# [19:39:36] Task 3 got rank 3
# [19:39:36] Task 0 got rank 0
# 2025-05-09 19:39:43,178 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:39:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:52 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:39:53,359 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:39:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:39:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:40:08,870 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# ICX Mean Squared Error (MSE): 3.437268689301406e-05   Accuracy (within 5% of true values): 99.77%
# 25/05/09 19:40:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:29 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:40:29,903 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:40:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:40:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:41:16,663 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:41:17] Task 1 got rank 1                                        (0 + 4) / 4]
# [19:41:17] Task 2 got rank 2
# [19:41:17] Task 0 got rank 0
# [19:41:17] Task 3 got rank 3
# 2025-05-09 19:41:25,324 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:41:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:41:35,775 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:41:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:41:57,580 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# NULS Mean Squared Error (MSE): 2.9122999205317496e-05   Accuracy (within 5% of true values): 95.78%
# 25/05/09 19:42:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:42:14,275 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:42:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:42:31,132 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:42:32] Task 0 got rank 0                                        (0 + 4) / 4]
# [19:42:32] Task 1 got rank 1
# [19:42:32] Task 2 got rank 2
# [19:42:32] Task 3 got rank 3
# 2025-05-09 19:42:39,432 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:42:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:42:49,763 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:42:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:42:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:43:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:43:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:44:06,763 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# FET Mean Squared Error (MSE): 7.099320769690262e-06   Accuracy (within 5% of true values): 99.56%
# 25/05/09 19:44:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:12 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:12 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:12 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:44:20,143 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:44:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:44:41,457 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:44:42] Task 1 got rank 1
# [19:44:42] Task 0 got rank 0
# [19:44:42] Task 3 got rank 3
# [19:44:42] Task 2 got rank 2
# 2025-05-09 19:44:49,818 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:44:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:44:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:44:59,626 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:45:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:45:12,981 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# ENJ Mean Squared Error (MSE): 0.004846064300129561   Accuracy (within 5% of true values): 81.61%
# 25/05/09 19:45:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:45:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:46:01,005 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:46:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:46:22,922 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:46:23] Task 0 got rank 0
# [19:46:23] Task 2 got rank 2
# [19:46:23] Task 3 got rank 3
# [19:46:23] Task 1 got rank 1
# 2025-05-09 19:46:32,479 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:46:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:46:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:46:54,219 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:47:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:47:12,889 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# BCH Mean Squared Error (MSE): 2015.368540818569   Accuracy (within 5% of true values): 26.78%
# 25/05/09 19:47:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:47:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:48:14,352 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:48:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:48:39,808 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [19:48:40] Task 3 got rank 3
# [19:48:40] Task 0 got rank 0
# [19:48:40] Task 1 got rank 1
# [19:48:40] Task 2 got rank 2
# 2025-05-09 19:48:49,711 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:48:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:48:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:49:08,129 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:49:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:49:21,994 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# ZIL Mean Squared Error (MSE): 1.7407537995320177e-06   Accuracy (within 5% of true values): 90.41%
# 25/05/09 19:49:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:49:39,149 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:49:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:49:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:49:52,623 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:49:53] Task 0 got rank 0                                        (0 + 4) / 4]
# [19:49:53] Task 1 got rank 1
# [19:49:53] Task 3 got rank 3
# [19:49:53] Task 2 got rank 2
# 2025-05-09 19:49:59,791 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:50:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:50:15,698 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:50:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:50:31,741 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# FTM Mean Squared Error (MSE): 0.00026543143714375723   Accuracy (within 5% of true values): 97.52%
# 25/05/09 19:50:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:50:49,005 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:50:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:50:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:51:04,470 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:51:05] Task 1 got rank 1                                        (0 + 4) / 4]
# [19:51:05] Task 2 got rank 2
# [19:51:05] Task 0 got rank 0
# [19:51:05] Task 3 got rank 3
# 2025-05-09 19:51:14,171 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 19:51:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:51:24,234 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 19:51:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:51:36,678 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# REN Mean Squared Error (MSE): 2.2701945412392404e-05   Accuracy (within 5% of true values): 82.39%
# 25/05/09 19:51:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:51:49,064 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 19:51:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 19:51:54 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 19:52:00,424 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [19:52:01] Task 1 got rank 1                                        (0 + 4) / 4]
# [19:52:01] Task 0 got rank 0
# [19:52:01] Task 3 got rank 3
# ...
# 25/05/09 20:15:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:15:10,222 INFO XGBoost-PySpark: _train_booster Training on CPUs 1]
# [20:15:11] Task 1 got rank 1[20:15:11] Task 2 got rank 2            (0 + 4) / 4]
#
# [20:15:11] Task 3 got rank 3
# [20:15:11] Task 0 got rank 0
# 2025-05-09 20:15:13,588 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:15:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:15:19,711 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:15:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:15:45,137 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# SHIB Mean Squared Error (MSE): 8.39304006517067e-14   Accuracy (within 5% of true values): 94.72%
# 25/05/09 20:15:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:53 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:15:56 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:16:01,489 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:16:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:16:12,206 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:16:13] Task 0 got rank 0
# [20:16:13] Task 1 got rank 1
# [20:16:13] Task 3 got rank 3
# [20:16:13] Task 2 got rank 2
# 2025-05-09 20:16:20,123 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:16:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:16:32,820 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:16:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:16:40,668 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# JUV Mean Squared Error (MSE): 0.006030834906449041   Accuracy (within 5% of true values): 96.62%
# 25/05/09 20:16:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:16:51,145 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:16:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:16:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:17:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:17:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:17:05,149 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:17:06] Task 0 got rank 0
# [20:17:06] Task 1 got rank 1
# [20:17:06] Task 2 got rank 2
# [20:17:06] Task 3 got rank 3
# 2025-05-09 20:17:10,930 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:17:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:17:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:17:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:18:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:18:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:18:47,104 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:18:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:18:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:10 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:20:16,575 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# FIS Mean Squared Error (MSE): 9.411405057634862e-05   Accuracy (within 5% of true values): 91.70%
# 25/05/09 20:20:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:20:24,027 INFO XGBoost-PySpark: _fit Running xgboost-2.1.3 on 4 workers with
# 	booster params: {'objective': 'reg:squarederror', 'device': 'cpu', 'max_depth': 6, 'eta': 0.1, 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# 25/05/09 20:20:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:20:34,770 INFO XGBoost-PySpark: _train_booster Training on CPUs 4]
# [20:20:35] Task 2 got rank 2
# [20:20:35] Task 0 got rank 0[20:20:35] Task 1 got rank 1
#
# [20:20:35] Task 3 got rank 3
# 2025-05-09 20:20:38,760 INFO XGBoost-PySpark: _fit Finished xgboost training!
# 25/05/09 20:20:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:20:43,169 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# 25/05/09 20:20:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/05/09 20:20:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2025-05-09 20:20:47,804 INFO XGBoost-PySpark: predict_udf Do the inference on the CPUs
# [Stage 724:>                                                        (0 + 1) / 1]
# EPS Mean Squared Error (MSE): 1.0302938870774501e-05   Accuracy (within 5% of true values): 98.84%
